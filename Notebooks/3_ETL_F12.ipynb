# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #  **ETL for functions 1 and 2**

# %% [markdown]
# Now, with the datasets unnested and organized, we are going to do some merges and data trasnformations in order to have the information required in a CSV file to develop these functions and models:

# %% [markdown]
# 1. **PlayTimeGenre**(`genre`: str) Function:
#
#   It should return the release year with the most played hours for the given `genre`.
#
#   Example of return: {"Release year with the most played hours for Genre X" : 2013}
#
# 2. **UserForGenre**(`genre`: str) Function:
#
#   It should return the user who has accumulated the most played hours for the given `genre` and a list of the accumulated playtime by release year.
#
#   Example of return: {"User with the most played hours for Genre X" : us213ndjss09sdf, "Playtime":[{Year: 2013, Hours: 203}, {Year: 2012, Hours: 100}, {Year: 2011, Hours: 23}]}

# %% [markdown]
# ### 1. Data Load:

# %%
import pandas as pd
import numpy as np

# %%
df_steam_games = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/steam_games_final.csv')
df_steam_games
# Out:
#               publisher                                             genres  \
# 0             Kotoshiro  ['Action', 'Casual', 'Indie', 'Simulation', 'S...
# 1      Making Fun, Inc.       ['Free to Play', 'Indie', 'RPG', 'Strategy']
# 2          Poolians.com  ['Casual', 'Free to Play', 'Indie', 'Simulatio...
# 3                  彼岸领域                  ['Action', 'Adventure', 'Casual']
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 32130   Ghost_RUS Games      ['Casual', 'Indie', 'Simulation', 'Strategy']
# 32131            Sacada                    ['Casual', 'Indie', 'Strategy']
# 32132      Laush Studio                  ['Indie', 'Racing', 'Simulation']
# 32133          SIXNAILS                                ['Casual', 'Indie']
# 32134               NaN                                                NaN
#
#                        app_name                     title  \
# ...

# %%
df_steam_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32135 entries, 0 to 32134
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     24073 non-null  object
#  1   genres        28852 non-null  object
#  2   app_name      32133 non-null  object
#  3   title         30085 non-null  object
#  4   url           32135 non-null  object
#  5   release_date  30068 non-null  object
#  6   tags          31972 non-null  object
#  7   reviews_url   32133 non-null  object
#  8   specs         31465 non-null  object
#  9   price         30758 non-null  object
#  10  early_access  32135 non-null  bool
#  11  id            32133 non-null  float64
#  12  developer     28836 non-null  object
# dtypes: bool(1), float64(1), object(11)
# memory usage: 3.0+ MB

# %%
df_users_items = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/users_items_final.csv')
df_users_items
# Out:
#                    user_id  items_count           steam_id  \
# 0        76561197970982479          277  76561197970982479
# 1        76561197970982479          277  76561197970982479
# 2        76561197970982479          277  76561197970982479
# 3        76561197970982479          277  76561197970982479
# 4        76561197970982479          277  76561197970982479
# ...                    ...          ...                ...
# 5170010  76561198329548331            7  76561198329548331
# 5170011  76561198329548331            7  76561198329548331
# 5170012  76561198329548331            7  76561198329548331
# 5170013  76561198329548331            7  76561198329548331
# 5170014  edward_tremethick            0  76561198331598578
#
#                                                   user_url   item_id  \
# 0        http://steamcommunity.com/profiles/76561197970...      10.0
# 1        http://steamcommunity.com/profiles/76561197970...      20.0
# ...

# %%
df_users_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5170015 entries, 0 to 5170014
# Data columns (total 8 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   user_id           object
#  1   items_count       int64
#  2   steam_id          int64
#  3   user_url          object
#  4   item_id           float64
#  5   item_name         object
#  6   playtime_forever  float64
#  7   playtime_2weeks   float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 315.6+ MB

# %% [markdown]
# **Step 1:**

# %% [markdown]
# df_steam_games has a column called `release_date`. We need to extract the year of this release date and place it in a new column called `release_year`. We ar going to do something similar as in the step 1.

# %%
df_steam_games
# Out:
#               publisher                                             genres  \
# 0             Kotoshiro  ['Action', 'Casual', 'Indie', 'Simulation', 'S...
# 1      Making Fun, Inc.       ['Free to Play', 'Indie', 'RPG', 'Strategy']
# 2          Poolians.com  ['Casual', 'Free to Play', 'Indie', 'Simulatio...
# 3                  彼岸领域                  ['Action', 'Adventure', 'Casual']
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 32130   Ghost_RUS Games      ['Casual', 'Indie', 'Simulation', 'Strategy']
# 32131            Sacada                    ['Casual', 'Indie', 'Strategy']
# 32132      Laush Studio                  ['Indie', 'Racing', 'Simulation']
# 32133          SIXNAILS                                ['Casual', 'Indie']
# 32134               NaN                                                NaN
#
#                        app_name                     title  \
# ...

# %% [markdown]
# As in the step 1, it is a good practice to check the NaN in the column 'release_date'.

# %%
mask = df_steam_games['release_date'].isna()
df_steam_games[mask]
# Out:
#               publisher                                            genres  \
# 4                   NaN                                               NaN
# 11                  NaN                                               NaN
# 19                  NaN                                               NaN
# 20                  NaN                                               NaN
# 22                  NaN                                               NaN
# ...                 ...                                               ...
# 32077               NaN                                               NaN
# 32084               NaN                     ['Action', 'Casual', 'Indie']
# 32085               NaN                                               NaN
# 32088  rechargecomplete  ['Action', 'Adventure', 'Indie', 'Early Access']
# 32134               NaN                                               NaN
#
#                    app_name              title  \
# ...

# %% [markdown]
# In this case, we can see that though the 'release_date' is in NaN, the entries have other information that can be useful.

# %% [markdown]
# Now, let's review the format of the dates in the column 'release_date', to check how can we extract the year.

# %%
df_steam_games['release_date'][:60]
# Out:
# 0     2018-01-04
# 1     2018-01-04
# 2     2017-07-24
# 3     2017-12-07
# 4            NaN
# 5     2018-01-04
# 6     2018-01-04
# 7     2018-01-04
# 8     2018-01-04
# 9     2018-01-04
# 10        Soon..
# 11           NaN
# 12    2018-01-04
# 13    2018-01-04
# 14    2018-01-03
# 15    2018-01-03
# 16    2018-01-03
# 17    2018-01-03
# 18    2018-01-03
# 19           NaN
# 20           NaN
# 21    2018-01-03
# 22           NaN
# 23    2017-12-22
# 24    2017-12-23
# 25    2018-01-03
# 26    2018-01-03
# 27    1997-06-30
# 28    1998-11-08
# 29    2016-11-25
# 30           NaN
# 31    2018-01-01
# 32    2018-01-01
# 33    2018-01-01
# 34    2018-01-01
# 35    2017-12-30
# 36           NaN
# 37    2018-01-01
# 38    2018-01-01
# 39    2006-07-06
# 40    2006-07-06
# 41    2006-07-11
# 42           NaN
# 43          2017
# 44     Beta测试已开启
# 45           NaN
# 46    2017-12-29
# 47    2018-03-30
# 48    2017-12-29
# 49    2017-12-29
# 50    2017-12-29
# 51           NaN
# ...

# %% [markdown]
# In the sample of the first 60 rows we can see that the normal format is YYYY-MM-DD. However, there are some NaN and strings that need to be considered. Also, there are entries with only the year. So we need to consider also this.

# %%
import re

# We create a function to extract the year considering the data that we have in the sample above.
def extract_year(date_str):
    if pd.notna(date_str):  #If the value is not NaN
        year_match = re.search(r'\b\d{4}\b', date_str) # We loo for the year following the format '\b\d{4}\b' using the function re.search()
        if year_match:
            return year_match.group()
    return np.NaN

# we apply the function to the column release_date
release_year = df_steam_games['release_date'].apply(extract_year)

# Mostrar el DataFrame resultante
release_year
# Out:
# 0        2018
# 1        2018
# 2        2017
# 3        2017
# 4         NaN
#          ...
# 32130    2018
# 32131    2018
# 32132    2018
# 32133    2017
# 32134     NaN
# Name: release_date, Length: 32135, dtype: object

# %% [markdown]
# Now we concatenate the column release_year with the dataframe steam_games:

# %%
df_steam_games_WY = pd.concat([df_steam_games, pd.DataFrame({'release_year': release_year})], axis=1)
df_steam_games_WY
# Out:
#               publisher                                             genres  \
# 0             Kotoshiro  ['Action', 'Casual', 'Indie', 'Simulation', 'S...
# 1      Making Fun, Inc.       ['Free to Play', 'Indie', 'RPG', 'Strategy']
# 2          Poolians.com  ['Casual', 'Free to Play', 'Indie', 'Simulatio...
# 3                  彼岸领域                  ['Action', 'Adventure', 'Casual']
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 32130   Ghost_RUS Games      ['Casual', 'Indie', 'Simulation', 'Strategy']
# 32131            Sacada                    ['Casual', 'Indie', 'Strategy']
# 32132      Laush Studio                  ['Indie', 'Racing', 'Simulation']
# 32133          SIXNAILS                                ['Casual', 'Indie']
# 32134               NaN                                                NaN
#
#                        app_name                     title  \
# ...

# %% [markdown]
# **Step 3:**

# %% [markdown]
# Having a dataframe with the item IDs for that specific `genre`, we can merge it with a dataframe that has the sum of 'playtime_forever' grouped by `item_id`. This information is found in the dataframe df_users_items. Now we have a new dataframe for a specific genre with the sum of hours played.

# %%
df_users_items
# Out:
#                    user_id  items_count           steam_id  \
# 0        76561197970982479          277  76561197970982479
# 1        76561197970982479          277  76561197970982479
# 2        76561197970982479          277  76561197970982479
# 3        76561197970982479          277  76561197970982479
# 4        76561197970982479          277  76561197970982479
# ...                    ...          ...                ...
# 5170010  76561198329548331            7  76561198329548331
# 5170011  76561198329548331            7  76561198329548331
# 5170012  76561198329548331            7  76561198329548331
# 5170013  76561198329548331            7  76561198329548331
# 5170014  edward_tremethick            0  76561198331598578
#
#                                                   user_url   item_id  \
# 0        http://steamcommunity.com/profiles/76561197970...      10.0
# 1        http://steamcommunity.com/profiles/76561197970...      20.0
# ...

# %% [markdown]
# Let's group by item_id summing the playtime_forever column. To so this, we can use the function "groupby()" of Pandas:

# %%
# Group by "item_id" and sum the values of "playtime_forever"
grouped_df_users_items = df_users_items.groupby(['item_id', 'user_id'])['playtime_forever'].sum().reset_index()

grouped_df_users_items.rename(columns={'playtime_forever': 'sum_playtime_forever'}, inplace=True)
grouped_df_users_items
# Out:
#           item_id               user_id  sum_playtime_forever
# 0            10.0            -GM-Dragon                  14.0
# 1            10.0            -KillZone-                 987.0
# 2            10.0                 -Mad-                   8.0
# 3            10.0               -SEVEN-                 617.0
# 4            10.0  -SatansLittleHelper-                 511.0
# ...           ...                   ...                   ...
# 5094077  529670.0                chidvd                   0.0
# 5094078  529670.0        fearlesskeeper                   0.0
# 5094079  529820.0           robinwalker                   0.0
# 5094080  530720.0            CSMisBeast                   0.0
# 5094081  530720.0        mayshowganmore                   0.0
#
# [5094082 rows x 3 columns]

# %% [markdown]
# We passed from 5,170,015 entries to 5,094,082 registers.

# %% [markdown]
# Now we need to merge the grouped dataframe grouped_df_users_items with the df_steam_games_WY in order to have all the information together and apply the functions:

# %%
df_steam_games_WY.rename(columns={'id': 'item_id'}, inplace=True)
df_steam_games_WY
# Out:
#               publisher                                             genres  \
# 0             Kotoshiro  ['Action', 'Casual', 'Indie', 'Simulation', 'S...
# 1      Making Fun, Inc.       ['Free to Play', 'Indie', 'RPG', 'Strategy']
# 2          Poolians.com  ['Casual', 'Free to Play', 'Indie', 'Simulatio...
# 3                  彼岸领域                  ['Action', 'Adventure', 'Casual']
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 32130   Ghost_RUS Games      ['Casual', 'Indie', 'Simulation', 'Strategy']
# 32131            Sacada                    ['Casual', 'Indie', 'Strategy']
# 32132      Laush Studio                  ['Indie', 'Racing', 'Simulation']
# 32133          SIXNAILS                                ['Casual', 'Indie']
# 32134               NaN                                                NaN
#
#                        app_name                     title  \
# ...

# %%
#Merging the dataframes by item_id.
merged_all_by_sumPTForever = pd.merge(grouped_df_users_items, df_steam_games_WY, on='item_id', how='inner')
merged_all_by_sumPTForever
# Out:
#           item_id               user_id  sum_playtime_forever  \
# 0            10.0            -GM-Dragon                  14.0
# 1            10.0            -KillZone-                 987.0
# 2            10.0                 -Mad-                   8.0
# 3            10.0               -SEVEN-                 617.0
# 4            10.0  -SatansLittleHelper-                 511.0
# ...           ...                   ...                   ...
# 4244807  528660.0            SirexPower                 182.0
# 4244808  528660.0          thugnificent                   0.0
# 4244809  529820.0           robinwalker                   0.0
# 4244810  530720.0            CSMisBeast                   0.0
# 4244811  530720.0        mayshowganmore                   0.0
#
#                   publisher                         genres          app_name  \
# 0                     Valve                     ['Action']    Counter-Strike
# ...

# %%
merged_all_by_sumPTForever.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4244812 entries, 0 to 4244811
# Data columns (total 16 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   item_id               float64
#  1   user_id               object
#  2   sum_playtime_forever  float64
#  3   publisher             object
#  4   genres                object
#  5   app_name              object
#  6   title                 object
#  7   url                   object
#  8   release_date          object
#  9   tags                  object
#  10  reviews_url           object
#  11  specs                 object
#  12  price                 object
#  13  early_access          bool
#  14  developer             object
#  15  release_year          object
# dtypes: bool(1), float64(2), object(13)
# memory usage: 522.2+ MB

# %% [markdown]
# Now we need to keep minimum columns that are requiered by the functions in order to save resources.
#
# Analyzing the functions, the only columns that we are going to need are the following:
#
# - user_id: We need these data for the function 2.
# - item_id: It is important for the ML model where the user needs to enter an item_id in order to receive 5 games that are similar to the one selected.
# - title: It is important for the ML model where the user needs to enter an item_id in order to receive 5 games that are similar to the one selected.
# - release_year: We need these data for the function 1 and 2.
# - genres: We need these data for the function 1 and 2.
# - sum_playtime_forever: We need these data for the function 1 and 2.

# %%
selected_columns = ['user_id','item_id','title','release_year','genres','sum_playtime_forever']
df_F12 = merged_all_by_sumPTForever[selected_columns]
df_F12
# Out:
#                       user_id   item_id             title release_year  \
# 0                  -GM-Dragon      10.0    Counter-Strike         2000
# 1                  -KillZone-      10.0    Counter-Strike         2000
# 2                       -Mad-      10.0    Counter-Strike         2000
# 3                     -SEVEN-      10.0    Counter-Strike         2000
# 4        -SatansLittleHelper-      10.0    Counter-Strike         2000
# ...                       ...       ...               ...          ...
# 4244807            SirexPower  528660.0         Spin Rush         2016
# 4244808          thugnificent  528660.0         Spin Rush         2016
# 4244809           robinwalker  529820.0               NaN          NaN
# 4244810            CSMisBeast  530720.0  Solitaire Royale         2016
# 4244811        mayshowganmore  530720.0  Solitaire Royale         2016
#
#                                 genres  sum_playtime_forever
# ...

# %% [markdown]
# In order to reduce the size of the dataframe we can eliminate the rows where genres are NaN, the sum_playtime_forever is 0.0 or the release_year is NaN.

# %% [markdown]
# First, let's check if there is any user in NaN:

# %%
mask = df_F12['user_id'].isna()
df_F12[mask]
# Out:
# Empty DataFrame
# Columns: [user_id, item_id, title, release_year, genres, sum_playtime_forever]
# Index: []

# %% [markdown]
# We can see that there is no user with NaN, so any NaN in the other remaining columns would eliminate the row to be considered by the functions. So, in this case, we can apply the function dropna() to all the dataframe:

# %%
df_F12.dropna(inplace=True)
df_F12
# Out:
# <ipython-input-48-16c7fcd4b8bb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_F12.dropna(inplace=True)
#                       user_id   item_id  \
# 0                  -GM-Dragon      10.0
# 1                  -KillZone-      10.0
# 2                       -Mad-      10.0
# 3                     -SEVEN-      10.0
# 4        -SatansLittleHelper-      10.0
# ...                       ...       ...
# 4244800     76561198159037032  527900.0
# 4244807            SirexPower  528660.0
# 4244808          thugnificent  528660.0
# 4244810            CSMisBeast  530720.0
# 4244811        mayshowganmore  530720.0
#
#                                              title release_year  \
# 0                                   Counter-Strike         2000
# ...

# %% [markdown]
# Finally, we need to eliminate the sum_playtime_forever in 0.0. These rows do not have any value for the functions:

# %%
mask = df_F12['sum_playtime_forever']!= 0.0
df_F12 = df_F12[mask]
df_F12
# Out:
#                       user_id   item_id  \
# 0                  -GM-Dragon      10.0
# 1                  -KillZone-      10.0
# 2                       -Mad-      10.0
# 3                     -SEVEN-      10.0
# 4        -SatansLittleHelper-      10.0
# ...                       ...       ...
# 4244776        mayshowganmore  527510.0
# 4244793                 lexby  527810.0
# 4244799          SmokaBluntos  527890.0
# 4244800     76561198159037032  527900.0
# 4244807            SirexPower  528660.0
#
#                                              title release_year  \
# 0                                   Counter-Strike         2000
# 1                                   Counter-Strike         2000
# 2                                   Counter-Strike         2000
# 3                                   Counter-Strike         2000
# 4                                   Counter-Strike         2000
# ...                                            ...          ...
# ...

# %%
df_F12.reset_index(drop=True, inplace=True)
df_F12
# Out:
#                       user_id   item_id  \
# 0                  -GM-Dragon      10.0
# 1                  -KillZone-      10.0
# 2                       -Mad-      10.0
# 3                     -SEVEN-      10.0
# 4        -SatansLittleHelper-      10.0
# ...                       ...       ...
# 2763972        mayshowganmore  527510.0
# 2763973                 lexby  527810.0
# 2763974          SmokaBluntos  527890.0
# 2763975     76561198159037032  527900.0
# 2763976            SirexPower  528660.0
#
#                                              title release_year  \
# 0                                   Counter-Strike         2000
# 1                                   Counter-Strike         2000
# 2                                   Counter-Strike         2000
# 3                                   Counter-Strike         2000
# 4                                   Counter-Strike         2000
# ...                                            ...          ...
# ...

# %% [markdown]
# Now we have in total 2,763,977 entries and 4 rows, which is the only data that we need to solve the functions.

# %%
df_F12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2763977 entries, 0 to 2763976
# Data columns (total 6 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   user_id               object
#  1   item_id               float64
#  2   title                 object
#  3   release_year          object
#  4   genres                object
#  5   sum_playtime_forever  float64
# dtypes: float64(2), object(4)
# memory usage: 126.5+ MB

# %% [markdown]
# We need to change the "title" type from object to string

# %%
df_F12['title'] = df_F12['title'].astype('string')
df_F12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2763977 entries, 0 to 2763976
# Data columns (total 6 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   user_id               object
#  1   item_id               float64
#  2   title                 string
#  3   release_year          object
#  4   genres                object
#  5   sum_playtime_forever  float64
# dtypes: float64(2), object(3), string(1)
# memory usage: 126.5+ MB
# <ipython-input-52-9bfb76e8eadd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_F12['title'] = df_F12['title'].astype('string')

# %% [markdown]
# We need to change the "release_year" type from object to int64

# %%
df_F12['release_year'] = df_F12['release_year'].astype('int64')
df_F12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2763977 entries, 0 to 2763976
# Data columns (total 6 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   user_id               object
#  1   item_id               float64
#  2   title                 string
#  3   release_year          int64
#  4   genres                object
#  5   sum_playtime_forever  float64
# dtypes: float64(2), int64(1), object(2), string(1)
# memory usage: 126.5+ MB
# <ipython-input-53-731ca712363f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_F12['release_year'] = df_F12['release_year'].astype('int64')

# %%
duplicados_item_id = df_F12['item_id'].duplicated()
df_F12[duplicados_item_id]
# Out:
#                       user_id   item_id                title  release_year  \
# 1                  -KillZone-      10.0       Counter-Strike          2000
# 2                       -Mad-      10.0       Counter-Strike          2000
# 3                     -SEVEN-      10.0       Counter-Strike          2000
# 4        -SatansLittleHelper-      10.0       Counter-Strike          2000
# 5                     -Ultrix      10.0       Counter-Strike          2000
# ...                       ...       ...                  ...           ...
# 2763967            kingholica  527340.0        What The Box?          2016
# 2763968               livaris  527340.0        What The Box?          2016
# 2763969             sky_track  527340.0        What The Box?          2016
# 2763970       theghostofbowie  527340.0        What The Box?          2016
# 2763972        mayshowganmore  527510.0  The Legions of Rome          2016
#
# ...

# %% [markdown]
# For the functions 1 and 2, we only require these 4 columns:
#
# - user_id
# - release_year
# - genres
# - sum_playtime_forever

# %%
columns_to_eliminate = ['item_id','title']
df_F12 = df_F12.drop(columns=columns_to_eliminate)
df_F12
# Out:
#                       user_id  release_year  \
# 0                  -GM-Dragon          2000
# 1                  -KillZone-          2000
# 2                       -Mad-          2000
# 3                     -SEVEN-          2000
# 4        -SatansLittleHelper-          2000
# ...                       ...           ...
# 2763972        mayshowganmore          2016
# 2763973                 lexby          2016
# 2763974          SmokaBluntos          2016
# 2763975     76561198159037032          2016
# 2763976            SirexPower          2016
#
#                                                 genres  sum_playtime_forever
# 0                                           ['Action']                  14.0
# 1                                           ['Action']                 987.0
# 2                                           ['Action']                   8.0
# 3                                           ['Action']                 617.0
# ...

# %% [markdown]
# Now we need to group by user_id summing sum_playtime_forever.

# %%
groupedF12 = df_F12.groupby(['user_id', 'release_year', 'genres'])['sum_playtime_forever'].sum().reset_index()
groupedF12
# Out:
#             user_id  release_year  \
# 0           --000--          2006
# 1           --000--          2009
# 2           --000--          2010
# 3           --000--          2011
# 4           --000--          2011
# ...             ...           ...
# 2241396  zzzmidmiss          2012
# 2241397  zzzmidmiss          2013
# 2241398  zzzmidmiss          2013
# 2241399  zzzmidmiss          2013
# 2241400  zzzmidmiss          2014
#
#                                                     genres  \
# 0                                  ['Indie', 'Simulation']
# 1                                               ['Action']
# 2                      ['Action', 'Free to Play', 'Indie']
# 3                  ['Action', 'Adventure', 'Indie', 'RPG']
# 4        ['Action', 'Free to Play', 'Massively Multipla...
# ...                                                    ...
# 2241396                                            ['RPG']
# 2241397            ['Action', 'Adventure', 'Indie', 'RPG']
# ...

# %% [markdown]
# We can see that there are some repeated release_years with the same genres. We need to group by the release_year and the user_id concatenating the genres and summing the sum_playtime_forever. Let's do it:

# %%
# We define a function to convert the string representation to a list format
def convert_to_list_format(s):
    try:
        # Remove brackets, split by ', ', and enclose each element in single quotes
        elements = s.strip('[]').split(', ')
        formatted_elements = [f"'{element}'" for element in elements]
        return formatted_elements
    except Exception as e:
        # Handle any exceptions that may occur during conversion
        return []

# We apply the conversion function to the 'genres' column
groupedF12['genres'] = groupedF12['genres'].apply(convert_to_list_format)

# Then, explode the 'genres' column so that each genre is in a separate row
groupedF12 = groupedF12.explode('genres')

# Then, group by 'user_id' and 'release_year', concatenating the genres and summing the hours
aggregated_df = groupedF12.groupby(['user_id', 'release_year']).agg({'genres': list, 'sum_playtime_forever': 'sum'}).reset_index()

# Now we have a DataFrame with genres in the format ['Genre1', 'Genre2']
aggregated_df
# Out:
#            user_id  release_year  \
# 0          --000--          2006
# 1          --000--          2009
# 2          --000--          2010
# 3          --000--          2011
# 4          --000--          2012
# ...            ...           ...
# 660198  zzzmidmiss          2010
# 660199  zzzmidmiss          2011
# 660200  zzzmidmiss          2012
# 660201  zzzmidmiss          2013
# 660202  zzzmidmiss          2014
#
#                                                    genres  \
# 0                             [''Indie'', ''Simulation'']
# 1                                            [''Action'']
# 2               [''Action'', ''Free to Play'', ''Indie'']
# 3       [''Action'', ''Adventure'', ''Indie'', ''RPG''...
# 4       [''Action'', ''Adventure'', ''Casual'', ''Indi...
# ...                                                   ...
# 660198  [''Action'', ''Free to Play'', ''Indie'', ''Ad...
# 660199  [''Action'', ''Free to Play'', ''Massively Mul...
# ...

# %%
import pandas as pd
import numpy as np

# Suppose aggregated_df is your DataFrame
# Define a function to convert the values
def convert_to_list(genres_array):
    return [element.strip("'") for element in genres_array]

# Apply the function to the 'genres' column and replace the column
aggregated_df['genres'] = aggregated_df['genres'].apply(convert_to_list)

aggregated_df
# Out:
#            user_id  release_year  \
# 0          --000--          2006
# 1          --000--          2009
# 2          --000--          2010
# 3          --000--          2011
# 4          --000--          2012
# ...            ...           ...
# 660198  zzzmidmiss          2010
# 660199  zzzmidmiss          2011
# 660200  zzzmidmiss          2012
# 660201  zzzmidmiss          2013
# 660202  zzzmidmiss          2014
#
#                                                    genres  \
# 0                                     [Indie, Simulation]
# 1                                                [Action]
# 2                           [Action, Free to Play, Indie]
# 3       [Action, Adventure, Indie, RPG, Action, Free t...
# 4       [Action, Adventure, Casual, Indie, RPG, Action...
# ...                                                   ...
# 660198  [Action, Free to Play, Indie, Adventure, Strat...
# 660199  [Action, Free to Play, Massively Multiplayer, ...
# ...

# %% [markdown]
# We are going to save the entire dataset in a CSV file to have a backup copy ready to be consumed in subsequent processes.

# %%
aggregated_df.to_csv('F12.csv', index=False)

# %% [markdown]
# Let's save it also in a parquet file due to it saves resources.

# %%
aggregated_df.to_parquet('F12.parquet', index=False)
